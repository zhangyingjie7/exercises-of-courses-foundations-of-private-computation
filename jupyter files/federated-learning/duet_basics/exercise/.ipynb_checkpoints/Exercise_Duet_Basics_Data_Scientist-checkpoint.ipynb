# %%
import syft as sy

# %% [markdown]
# # Part 1: Join the Duet Server the Data Owner connected to

# %%
duet = sy.join_duet(loopback=True)
# Out:
# 🎤  🎸  ♪♪♪ Joining Duet ♫♫♫  🎻  🎹
#
# ♫♫♫ > DISCLAIMER: Duet is an experimental feature currently in beta.
# ♫♫♫ > Use at your own risk.
#
#
#     > ❤️ Love Duet? Please consider supporting our community!
#     > https://github.com/sponsors/OpenMined
#
# ♫♫♫ > Punching through firewall to OpenGrid Network Node at:
# ♫♫♫ > http://ec2-18-218-7-180.us-east-2.compute.amazonaws.com:5000
# ♫♫♫ >
# ♫♫♫ > ...waiting for response from OpenGrid Network...
# ♫♫♫ > DONE!
# d:\program files\python\python37\tutorial-env\lib\site-packages\aiortc\rtcdtlstransport.py:211: CryptographyDeprecationWarning: This version of cryptography contains a temporary pyOpenSSL fallback path. Upgrade pyOpenSSL now.
#   _openssl_assert(lib.SSL_CTX_use_certificate(ctx, self._cert._x509) == 1)  # type: ignore
# d:\program files\python\python37\tutorial-env\lib\site-packages\aiortc\rtcdtlstransport.py:186: CryptographyDeprecationWarning: This version of cryptography contains a temporary pyOpenSSL fallback path. Upgrade pyOpenSSL now.
#   value=certificate_digest(self._cert._x509),  # type: ignore
# ♫♫♫ > CONNECTED!

# %% [markdown]
# ### <img src="https://github.com/OpenMined/design-assets/raw/master/logos/OM/mark-primary-light.png" alt="he-black-box" width="100"/> Checkpoint 0 : Now STOP and run the Data Owner notebook until Checkpoint 1.

# %% [markdown]
# # Part 2: Search for Available Data

# %%
# The data scientist can check the list of searchable data in Data Owner's duet store
duet.store.pandas
# Out:
#                                         ID                  Tags  \
# 0  <UID: 103a88f6b6854d3884a3c04e0a0c1eaa>  [HEIGHTS of GROUP A]
# 1  <UID: e6581fbfa96849de914373f844f27aef>  [WEIGHTS of GROUP A]
#
#                                          Description             object_type
# 0  This is a list of heights (cm) of GROUP A - 6 ...  <class 'torch.Tensor'>
# 1  This is a list of body weights (kg) of GROUP A...  <class 'torch.Tensor'>

# %%
# Data Scientist finds that there are Heights and Weights of a group of people. There are some analysis he/she can do with them together.

heights_ptr = duet.store[0]
weights_ptr = duet.store[1]

# heights_ptr is a reference to the height dataset remotely available on data owner's server
print(heights_ptr)

# weights_ptr is a reference to the weight dataset remotely available on data owner's server
print(weights_ptr)
# Out:
# <syft.proxy.torch.TensorPointer object at 0x0000026C4F1E1470>
# <syft.proxy.torch.TensorPointer object at 0x0000026C4F1E1A58>

# %% [markdown]
# ## Calculate BMI (Body Mass Index) and weight status
#
# Using the heights and weights pointers of the people of Group A, calculate their BMI and get a pointer to their individual BMI. From the BMI pointers, you can check if a person is normal-weight, overweight or obese, without knowing their actual heights and weights and even BMI values.
#
#     BMI from 19 to 24 - Normal
#     BMI from 25 to 29 - Overweight
#     BMI from 30 to 39 - Obese
#
#     BMI = [weight (kg) / (height (cm)^2)] x 10,000
#     Hint: run duet.torch and find the required operators

# %% [markdown]
# One amazing thing about pointers is that from a pointer to a list of items, we can get the pointers to each item in the list. As example, here we have weights_ptr pointing to the weight-list, but from that we can also get the pointer to each weight and perform computation on each of them without even the knowing the value! Below code will show you how to access the pointers to each weight and height from the list pointer.

# %%
for i in range(6):
    print("Pointer to Weight of person", i + 1, weights_ptr[i])
    print("Pointer to Height of person", i + 1, heights_ptr[i])
# Out:
# Pointer to Weight of person 1 <syft.proxy.torch.TensorPointer object at 0x0000026C4F1E1278>
# Pointer to Height of person 1 <syft.proxy.torch.TensorPointer object at 0x0000026C4F360438>
# Pointer to Weight of person 2 <syft.proxy.torch.TensorPointer object at 0x0000026C4F360438>
# Pointer to Height of person 2 <syft.proxy.torch.TensorPointer object at 0x0000026C4EDE0F98>
# Pointer to Weight of person 3 <syft.proxy.torch.TensorPointer object at 0x0000026C4EDE0F98>
# Pointer to Height of person 3 <syft.proxy.torch.TensorPointer object at 0x0000026C4EDE0F98>
# Pointer to Weight of person 4 <syft.proxy.torch.TensorPointer object at 0x0000026C4EDE0F98>
# Pointer to Height of person 4 <syft.proxy.torch.TensorPointer object at 0x0000026C4EDE0F98>
# Pointer to Weight of person 5 <syft.proxy.torch.TensorPointer object at 0x0000026C4EDE0F98>
# Pointer to Height of person 5 <syft.proxy.torch.TensorPointer object at 0x0000026C4EDE0F98>
# Pointer to Weight of person 6 <syft.proxy.torch.TensorPointer object at 0x0000026C4EDE0F98>
# Pointer to Height of person 6 <syft.proxy.torch.TensorPointer object at 0x0000026C4EDE0F98>

# %%
duet.torch
# Out:
# Module:
# 	.Tensor -> <syft.ast.klass.Class object at 0x0000026C4EE60590>
# 	.BFloat16Tensor -> <syft.ast.klass.Class object at 0x0000026C4EE605F8>
# 	.BoolTensor -> <syft.ast.klass.Class object at 0x0000026C4EE60660>
# 	.ByteTensor -> <syft.ast.klass.Class object at 0x0000026C4EE606C8>
# 	.CharTensor -> <syft.ast.klass.Class object at 0x0000026C4EE60730>
# 	.DoubleTensor -> <syft.ast.klass.Class object at 0x0000026C4EE60798>
# 	.FloatTensor -> <syft.ast.klass.Class object at 0x0000026C4EE60800>
# 	.HalfTensor -> <syft.ast.klass.Class object at 0x0000026C4EE60868>
# 	.IntTensor -> <syft.ast.klass.Class object at 0x0000026C4EE608D0>
# 	.LongTensor -> <syft.ast.klass.Class object at 0x0000026C4EE60938>
# 	.ShortTensor -> <syft.ast.klass.Class object at 0x0000026C4EE609A0>
# 	.nn -> Module:
# 		.Parameter -> <syft.ast.klass.Class object at 0x0000026C4EE60AD8>
# 		.Module -> <syft.ast.klass.Class object at 0x0000026C4EF60BA8>
# 		.Conv2d -> <syft.ast.klass.Class object at 0x0000026C4EF64118>
# 		.Dropout2d -> <syft.ast.klass.Class object at 0x0000026C4EF64528>
# 		.Linear -> <syft.ast.klass.Class object at 0x0000026C4EF64868>
# 		.functional -> Module:
# 			.relu -> <syft.ast.callable.Callable object at 0x0000026C4EF68118>
# 			.gelu -> <syft.ast.callable.Callable object at 0x0000026C4EF68180>
# 			.max_pool2d -> <syft.ast.callable.Callable object at 0x0000026C4EF681E8>
# 			.log_softmax -> <syft.ast.callable.Callable object at 0x0000026C4EF68250>
# 			.cosine_embedding_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF6FE80>
# 			.ctc_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF6FEE8>
# 			.hinge_embedding_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF6FF50>
# 			.l1_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF74048>
# 			.margin_ranking_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF740B0>
# 			.mse_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF74118>
# 			.multi_margin_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF74180>
# 			.multilabel_margin_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF741E8>
# 			.multilabel_soft_margin_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF74250>
# 			.nll_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF742B8>
# 			.cross_entropy -> <syft.ast.callable.Callable object at 0x0000026C4EF74320>
# 			.poisson_nll_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF74388>
# 			.smooth_l1_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF743F0>
# 			.soft_margin_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF74458>
# 			.triplet_margin_loss -> <syft.ast.callable.Callable object at 0x0000026C4EF744C0>
#
# 		.Sequential -> <syft.ast.klass.Class object at 0x0000026C4EF6FB40>
# 		.AdaptiveLogSoftmaxWithLoss -> <syft.ast.klass.Class object at 0x0000026C4EF74528>
# 		.BCELoss -> <syft.ast.klass.Class object at 0x0000026C4EF745F8>
# 		.BCEWithLogitsLoss -> <syft.ast.klass.Class object at 0x0000026C4EF746C8>
# 		.CTCLoss -> <syft.ast.klass.Class object at 0x0000026C4EF74798>
# 		.CrossEntropyLoss -> <syft.ast.klass.Class object at 0x0000026C4EF74868>
# 		.CosineEmbeddingLoss -> <syft.ast.klass.Class object at 0x0000026C4EF74938>
# 		.HingeEmbeddingLoss -> <syft.ast.klass.Class object at 0x0000026C4EF74A08>
# 		.KLDivLoss -> <syft.ast.klass.Class object at 0x0000026C4EF74AD8>
# 		.L1Loss -> <syft.ast.klass.Class object at 0x0000026C4EF74BA8>
# 		.MSELoss -> <syft.ast.klass.Class object at 0x0000026C4EF74C78>
# 		.MarginRankingLoss -> <syft.ast.klass.Class object at 0x0000026C4EF74D48>
# 		.MultiLabelMarginLoss -> <syft.ast.klass.Class object at 0x0000026C4EF74E18>
# 		.MultiLabelSoftMarginLoss -> <syft.ast.klass.Class object at 0x0000026C4EF74EE8>
# 		.MultiMarginLoss -> <syft.ast.klass.Class object at 0x0000026C4EF7A048>
# 		.NLLLoss -> <syft.ast.klass.Class object at 0x0000026C4EF7A118>
# 		.NLLLoss2d -> <syft.ast.klass.Class object at 0x0000026C4EF7A1E8>
# 		.PoissonNLLLoss -> <syft.ast.klass.Class object at 0x0000026C4EF7A2B8>
# 		.SmoothL1Loss -> <syft.ast.klass.Class object at 0x0000026C4EF7A388>
# 		.SoftMarginLoss -> <syft.ast.klass.Class object at 0x0000026C4EF7A458>
# 		.TripletMarginLoss -> <syft.ast.klass.Class object at 0x0000026C4EF7A528>
# 		.AdaptiveAvgPool1d -> <syft.ast.klass.Class object at 0x0000026C4EF7A5F8>
# 		.AdaptiveAvgPool2d -> <syft.ast.klass.Class object at 0x0000026C4EF7AA08>
# 		.AdaptiveAvgPool3d -> <syft.ast.klass.Class object at 0x0000026C4EF7AE18>
# 		.AdaptiveMaxPool1d -> <syft.ast.klass.Class object at 0x0000026C4EF802B8>
# 		.AdaptiveMaxPool2d -> <syft.ast.klass.Class object at 0x0000026C4EF806C8>
# 		.AdaptiveMaxPool3d -> <syft.ast.klass.Class object at 0x0000026C4EF80AD8>
# 		.AlphaDropout -> <syft.ast.klass.Class object at 0x0000026C4EF80EE8>
# 		.AvgPool1d -> <syft.ast.klass.Class object at 0x0000026C4EF86388>
# 		.AvgPool2d -> <syft.ast.klass.Class object at 0x0000026C4EF86798>
# 		.AvgPool3d -> <syft.ast.klass.Class object at 0x0000026C4EF86BA8>
# 		.BatchNorm1d -> <syft.ast.klass.Class object at 0x0000026C4EF8B048>
# 		.BatchNorm2d -> <syft.ast.klass.Class object at 0x0000026C4EF8B458>
# 		.BatchNorm3d -> <syft.ast.klass.Class object at 0x0000026C4EF8B868>
# 		.Bilinear -> <syft.ast.klass.Class object at 0x0000026C4EF8BC78>
# 		.CELU -> <syft.ast.klass.Class object at 0x0000026C4EF91118>
# 		.ConstantPad1d -> <syft.ast.klass.Class object at 0x0000026C4EF91528>
# 		.ConstantPad2d -> <syft.ast.klass.Class object at 0x0000026C4EF91938>
# 		.ConstantPad3d -> <syft.ast.klass.Class object at 0x0000026C4EF91D48>
# 		.Container -> <syft.ast.klass.Class object at 0x0000026C4EF981E8>
# 		.Conv1d -> <syft.ast.klass.Class object at 0x0000026C4EF985F8>
# 		.Conv3d -> <syft.ast.klass.Class object at 0x0000026C4EF98A08>
# 		.ConvTranspose1d -> <syft.ast.klass.Class object at 0x0000026C4EF98E18>
# 		.ConvTranspose2d -> <syft.ast.klass.Class object at 0x0000026C4EF9D2B8>
# 		.ConvTranspose3d -> <syft.ast.klass.Class object at 0x0000026C4EF9D6C8>
# 		.CosineSimilarity -> <syft.ast.klass.Class object at 0x0000026C4EF9DAD8>
# 		.CrossMapLRN2d -> <syft.ast.klass.Class object at 0x0000026C4EF9DEE8>
# 		.DataParallel -> <syft.ast.klass.Class object at 0x0000026C4EFA2388>
# 		.Dropout -> <syft.ast.klass.Class object at 0x0000026C4EFA2798>
# 		.Dropout3d -> <syft.ast.klass.Class object at 0x0000026C4EFA2C78>
# 		.ELU -> <syft.ast.klass.Class object at 0x0000026C4EFA7118>
# 		.Embedding -> <syft.ast.klass.Class object at 0x0000026C4EFA7528>
# 		.EmbeddingBag -> <syft.ast.klass.Class object at 0x0000026C4EFA7938>
# 		.FeatureAlphaDropout -> <syft.ast.klass.Class object at 0x0000026C4EFA7D48>
# 		.Flatten -> <syft.ast.klass.Class object at 0x0000026C4EFAE1E8>
# 		.Fold -> <syft.ast.klass.Class object at 0x0000026C4EFAE5F8>
# 		.FractionalMaxPool2d -> <syft.ast.klass.Class object at 0x0000026C4EFAEA08>
# 		.FractionalMaxPool3d -> <syft.ast.klass.Class object at 0x0000026C4EFAEE18>
# 		.GELU -> <syft.ast.klass.Class object at 0x0000026C4EFB32B8>
# 		.GLU -> <syft.ast.klass.Class object at 0x0000026C4EFB36C8>
# 		.GRU -> <syft.ast.klass.Class object at 0x0000026C4EFB3AD8>
# 		.GRUCell -> <syft.ast.klass.Class object at 0x0000026C4EFB3EE8>
# 		.GroupNorm -> <syft.ast.klass.Class object at 0x0000026C4EFB8388>
# 		.Hardshrink -> <syft.ast.klass.Class object at 0x0000026C4EFB8798>
# 		.Hardsigmoid -> <syft.ast.klass.Class object at 0x0000026C4EFB8BA8>
# 		.Hardswish -> <syft.ast.klass.Class object at 0x0000026C4EFB8F50>
# 		.Hardtanh -> <syft.ast.klass.Class object at 0x0000026C4EFBF388>
# 		.Identity -> <syft.ast.klass.Class object at 0x0000026C4EFBF798>
# 		.InstanceNorm1d -> <syft.ast.klass.Class object at 0x0000026C4EFBFBA8>
# 		.InstanceNorm2d -> <syft.ast.klass.Class object at 0x0000026C4EFC3048>
# 		.InstanceNorm3d -> <syft.ast.klass.Class object at 0x0000026C4EFC3458>
# 		.LPPool1d -> <syft.ast.klass.Class object at 0x0000026C4EFC3868>
# 		.LPPool2d -> <syft.ast.klass.Class object at 0x0000026C4EFC3C78>
# 		.LSTM -> <syft.ast.klass.Class object at 0x0000026C4EFCA118>
# 		.LSTMCell -> <syft.ast.klass.Class object at 0x0000026C4EFCA528>
# 		.LayerNorm -> <syft.ast.klass.Class object at 0x0000026C4EFCA938>
# 		.LeakyReLU -> <syft.ast.klass.Class object at 0x0000026C4EFCAD48>
# 		.LocalResponseNorm -> <syft.ast.klass.Class object at 0x0000026C4EFCF1E8>
# 		.LogSigmoid -> <syft.ast.klass.Class object at 0x0000026C4EFCF5F8>
# 		.LogSoftmax -> <syft.ast.klass.Class object at 0x0000026C4EFCFA08>
# 		.MaxPool1d -> <syft.ast.klass.Class object at 0x0000026C4EFCFE18>
# 		.MaxPool2d -> <syft.ast.klass.Class object at 0x0000026C4EFD62B8>
# 		.MaxPool3d -> <syft.ast.klass.Class object at 0x0000026C4EFD66C8>
# 		.MaxUnpool1d -> <syft.ast.klass.Class object at 0x0000026C4EFD6AD8>
# 		.MaxUnpool2d -> <syft.ast.klass.Class object at 0x0000026C4EFD6EE8>
# 		.MaxUnpool3d -> <syft.ast.klass.Class object at 0x0000026C4EFDB388>
# 		.ModuleDict -> <syft.ast.klass.Class object at 0x0000026C4EFDB798>
# 		.ModuleList -> <syft.ast.klass.Class object at 0x0000026C4EFDBBA8>
# 		.MultiheadAttention -> <syft.ast.klass.Class object at 0x0000026C4EFE1118>
# 		.PReLU -> <syft.ast.klass.Class object at 0x0000026C4EFE1528>
# 		.PairwiseDistance -> <syft.ast.klass.Class object at 0x0000026C4EFE1938>
# 		.PixelShuffle -> <syft.ast.klass.Class object at 0x0000026C4EFE1D48>
# 		.RNN -> <syft.ast.klass.Class object at 0x0000026C4EFE81E8>
# 		.RNNBase -> <syft.ast.klass.Class object at 0x0000026C4EFE85F8>
# 		.RNNCell -> <syft.ast.klass.Class object at 0x0000026C4EFE8A08>
# 		.RNNCellBase -> <syft.ast.klass.Class object at 0x0000026C4EFE8E18>
# 		.RReLU -> <syft.ast.klass.Class object at 0x0000026C4EFEE2B8>
# 		.ReLU -> <syft.ast.klass.Class object at 0x0000026C4EFEE6C8>
# 		.ReLU6 -> <syft.ast.klass.Class object at 0x0000026C4EFEEAD8>
# 		.ReflectionPad1d -> <syft.ast.klass.Class object at 0x0000026C4EFEEEE8>
# 		.ReflectionPad2d -> <syft.ast.klass.Class object at 0x0000026C4EFF5388>
# 		.ReplicationPad1d -> <syft.ast.klass.Class object at 0x0000026C4EFF5798>
# 		.ReplicationPad2d -> <syft.ast.klass.Class object at 0x0000026C4EFF5BA8>
# 		.ReplicationPad3d -> <syft.ast.klass.Class object at 0x0000026C4EFF9048>
# 		.SELU -> <syft.ast.klass.Class object at 0x0000026C4EFF9458>
# 		.Sigmoid -> <syft.ast.klass.Class object at 0x0000026C4EFF99A0>
# 		.Softmax -> <syft.ast.klass.Class object at 0x0000026C4EFF9DB0>
# 		.Softmax2d -> <syft.ast.klass.Class object at 0x0000026C4EFFF250>
# 		.Softmin -> <syft.ast.klass.Class object at 0x0000026C4EFFF660>
# 		.Softplus -> <syft.ast.klass.Class object at 0x0000026C4EFFFA70>
# 		.Softshrink -> <syft.ast.klass.Class object at 0x0000026C4EFFFE80>
# 		.Softsign -> <syft.ast.klass.Class object at 0x0000026C4F007320>
# 		.SyncBatchNorm -> <syft.ast.klass.Class object at 0x0000026C4F007730>
# 		.Tanh -> <syft.ast.klass.Class object at 0x0000026C4F007B40>
# 		.Tanhshrink -> <syft.ast.klass.Class object at 0x0000026C4F007F50>
# 		.Threshold -> <syft.ast.klass.Class object at 0x0000026C4F00D3F0>
# 		.Transformer -> <syft.ast.klass.Class object at 0x0000026C4F00D800>
# 		.TransformerDecoder -> <syft.ast.klass.Class object at 0x0000026C4F00DC10>
# 		.TransformerDecoderLayer -> <syft.ast.klass.Class object at 0x0000026C4F0130B0>
# 		.TransformerEncoder -> <syft.ast.klass.Class object at 0x0000026C4F013590>
# 		.TransformerEncoderLayer -> <syft.ast.klass.Class object at 0x0000026C4F0139A0>
# 		.Unfold -> <syft.ast.klass.Class object at 0x0000026C4F013E80>
# 		.Upsample -> <syft.ast.klass.Class object at 0x0000026C4F018320>
# 		.UpsamplingBilinear2d -> <syft.ast.klass.Class object at 0x0000026C4F018730>
# 		.UpsamplingNearest2d -> <syft.ast.klass.Class object at 0x0000026C4F018BA8>
# 		.ZeroPad2d -> <syft.ast.klass.Class object at 0x0000026C4F01D048>
#
# 	.return_types -> Module:
# 		.cummax -> <syft.ast.klass.Class object at 0x0000026C4EEBC180>
# 		.cummin -> <syft.ast.klass.Class object at 0x0000026C4EEBC1E8>
# 		.eig -> <syft.ast.klass.Class object at 0x0000026C4EEBC250>
# 		.kthvalue -> <syft.ast.klass.Class object at 0x0000026C4EEBC2B8>
# 		.lstsq -> <syft.ast.klass.Class object at 0x0000026C4EEBC320>
# 		.slogdet -> <syft.ast.klass.Class object at 0x0000026C4EEBC388>
# 		.qr -> <syft.ast.klass.Class object at 0x0000026C4EEBC3F0>
# 		.mode -> <syft.ast.klass.Class object at 0x0000026C4EEBC458>
# 		.solve -> <syft.ast.klass.Class object at 0x0000026C4EEBC4C0>
# 		.sort -> <syft.ast.klass.Class object at 0x0000026C4EEBC528>
# 		.symeig -> <syft.ast.klass.Class object at 0x0000026C4EEBC590>
# 		.topk -> <syft.ast.klass.Class object at 0x0000026C4EEBC5F8>
# 		.triangular_solve -> <syft.ast.klass.Class object at 0x0000026C4EEBC660>
# 		.svd -> <syft.ast.klass.Class object at 0x0000026C4EEBC6C8>
# 		.geqrf -> <syft.ast.klass.Class object at 0x0000026C4EEBC730>
# 		.median -> <syft.ast.klass.Class object at 0x0000026C4EEBC798>
# 		.max -> <syft.ast.klass.Class object at 0x0000026C4EEBC800>
# 		.min -> <syft.ast.klass.Class object at 0x0000026C4EEBC868>
#
# 	.Size -> <syft.ast.klass.Class object at 0x0000026C4EF31E80>
# 	.set_grad_enabled -> <syft.ast.klass.Class object at 0x0000026C4EF37250>
# 	.zeros -> <syft.ast.callable.Callable object at 0x0000026C4EF372B8>
# 	.randn -> <syft.ast.callable.Callable object at 0x0000026C4EF37320>
# 	.ones_like -> <syft.ast.callable.Callable object at 0x0000026C4EF37388>
# 	.arange -> <syft.ast.callable.Callable object at 0x0000026C4EF374C0>
# 	.abs_ -> <syft.ast.callable.Callable object at 0x0000026C4EF37528>
# 	.abs -> <syft.ast.callable.Callable object at 0x0000026C4EF37590>
# 	.acos_ -> <syft.ast.callable.Callable object at 0x0000026C4EF375F8>
# 	.acos -> <syft.ast.callable.Callable object at 0x0000026C4EF37660>
# 	.add -> <syft.ast.callable.Callable object at 0x0000026C4EF376C8>
# 	.addbmm -> <syft.ast.callable.Callable object at 0x0000026C4EF37730>
# 	.addcdiv -> <syft.ast.callable.Callable object at 0x0000026C4EF37798>
# 	.addcmul -> <syft.ast.callable.Callable object at 0x0000026C4EF37800>
# 	.addmm -> <syft.ast.callable.Callable object at 0x0000026C4EF37868>
# 	.addmv_ -> <syft.ast.callable.Callable object at 0x0000026C4EF378D0>
# 	.addmv -> <syft.ast.callable.Callable object at 0x0000026C4EF37938>
# 	.addr -> <syft.ast.callable.Callable object at 0x0000026C4EF379A0>
# 	.all -> <syft.ast.callable.Callable object at 0x0000026C4EF37A08>
# 	.allclose -> <syft.ast.callable.Callable object at 0x0000026C4EF37A70>
# 	.angle -> <syft.ast.callable.Callable object at 0x0000026C4EF37AD8>
# 	.any -> <syft.ast.callable.Callable object at 0x0000026C4EF37B40>
# 	.argmax -> <syft.ast.callable.Callable object at 0x0000026C4EF37BA8>
# 	.argmin -> <syft.ast.callable.Callable object at 0x0000026C4EF37C10>
# 	.argsort -> <syft.ast.callable.Callable object at 0x0000026C4EF37C78>
# 	.as_strided_ -> <syft.ast.callable.Callable object at 0x0000026C4EF37CE0>
# 	.as_strided -> <syft.ast.callable.Callable object at 0x0000026C4EF37D48>
# 	.asin_ -> <syft.ast.callable.Callable object at 0x0000026C4EF37DB0>
# 	.asin -> <syft.ast.callable.Callable object at 0x0000026C4EF37E18>
# 	.atan_ -> <syft.ast.callable.Callable object at 0x0000026C4EF37E80>
# 	.atan -> <syft.ast.callable.Callable object at 0x0000026C4EF37EE8>
# 	.atan2 -> <syft.ast.callable.Callable object at 0x0000026C4EF37F50>
# 	.baddbmm -> <syft.ast.callable.Callable object at 0x0000026C4EF3B048>
# 	.bernoulli -> <syft.ast.callable.Callable object at 0x0000026C4EF3B0B0>
# 	.bitwise_and -> <syft.ast.callable.Callable object at 0x0000026C4EF3B118>
# 	.bitwise_not -> <syft.ast.callable.Callable object at 0x0000026C4EF3B180>
# 	.bitwise_or -> <syft.ast.callable.Callable object at 0x0000026C4EF3B1E8>
# 	.bitwise_xor -> <syft.ast.callable.Callable object at 0x0000026C4EF3B250>
# 	.bmm -> <syft.ast.callable.Callable object at 0x0000026C4EF3B2B8>
# 	.cat -> <syft.ast.callable.Callable object at 0x0000026C4EF3B320>
# 	.ceil_ -> <syft.ast.callable.Callable object at 0x0000026C4EF3B388>
# 	.ceil -> <syft.ast.callable.Callable object at 0x0000026C4EF3B3F0>
# 	.cholesky_inverse -> <syft.ast.callable.Callable object at 0x0000026C4EF3B458>
# 	.cholesky_solve -> <syft.ast.callable.Callable object at 0x0000026C4EF3B4C0>
# 	.cholesky -> <syft.ast.callable.Callable object at 0x0000026C4EF3B528>
# 	.chunk -> <syft.ast.callable.Callable object at 0x0000026C4EF3B590>
# 	.clamp_ -> <syft.ast.callable.Callable object at 0x0000026C4EF3B5F8>
# 	.clamp_max_ -> <syft.ast.callable.Callable object at 0x0000026C4EF3B660>
# 	.clamp_max -> <syft.ast.callable.Callable object at 0x0000026C4EF3B6C8>
# 	.clamp_min_ -> <syft.ast.callable.Callable object at 0x0000026C4EF3B730>
# 	.clamp_min -> <syft.ast.callable.Callable object at 0x0000026C4EF3B798>
# 	.clamp -> <syft.ast.callable.Callable object at 0x0000026C4EF3B800>
# 	.clone -> <syft.ast.callable.Callable object at 0x0000026C4EF3B868>
# 	.conj -> <syft.ast.callable.Callable object at 0x0000026C4EF3B8D0>
# 	.cos_ -> <syft.ast.callable.Callable object at 0x0000026C4EF3B938>
# 	.cos -> <syft.ast.callable.Callable object at 0x0000026C4EF3B9A0>
# 	.cosh_ -> <syft.ast.callable.Callable object at 0x0000026C4EF3BA08>
# 	.cosh -> <syft.ast.callable.Callable object at 0x0000026C4EF3BA70>
# 	.cross -> <syft.ast.callable.Callable object at 0x0000026C4EF3BAD8>
# 	.cummax -> <syft.ast.callable.Callable object at 0x0000026C4EF3BB40>
# 	.cummin -> <syft.ast.callable.Callable object at 0x0000026C4EF3BBA8>
# 	.cumprod -> <syft.ast.callable.Callable object at 0x0000026C4EF3BC10>
# 	.cumsum -> <syft.ast.callable.Callable object at 0x0000026C4EF3BC78>
# 	.dequantize -> <syft.ast.callable.Callable object at 0x0000026C4EF3BCE0>
# 	.det -> <syft.ast.callable.Callable object at 0x0000026C4EF3BD48>
# 	.detach -> <syft.ast.callable.Callable object at 0x0000026C4EF3BDB0>
# 	.diag_embed -> <syft.ast.callable.Callable object at 0x0000026C4EF3BE18>
# 	.diag -> <syft.ast.callable.Callable object at 0x0000026C4EF3BE80>
# 	.diagflat -> <syft.ast.callable.Callable object at 0x0000026C4EF3BEE8>
# 	.diagonal -> <syft.ast.callable.Callable object at 0x0000026C4EF3BF50>
# 	.digamma -> <syft.ast.callable.Callable object at 0x0000026C4EF40048>
# 	.dist -> <syft.ast.callable.Callable object at 0x0000026C4EF400B0>
# 	.div -> <syft.ast.callable.Callable object at 0x0000026C4EF40118>
# 	.dot -> <syft.ast.callable.Callable object at 0x0000026C4EF40180>
# 	.eig -> <syft.ast.callable.Callable object at 0x0000026C4EF401E8>
# 	.eq -> <syft.ast.callable.Callable object at 0x0000026C4EF40250>
# 	.equal -> <syft.ast.callable.Callable object at 0x0000026C4EF402B8>
# 	.erf_ -> <syft.ast.callable.Callable object at 0x0000026C4EF40320>
# 	.erf -> <syft.ast.callable.Callable object at 0x0000026C4EF40388>
# 	.erfc_ -> <syft.ast.callable.Callable object at 0x0000026C4EF403F0>
# 	.erfc -> <syft.ast.callable.Callable object at 0x0000026C4EF40458>
# 	.erfinv -> <syft.ast.callable.Callable object at 0x0000026C4EF404C0>
# 	.exp_ -> <syft.ast.callable.Callable object at 0x0000026C4EF40528>
# 	.exp -> <syft.ast.callable.Callable object at 0x0000026C4EF40590>
# 	.expm1_ -> <syft.ast.callable.Callable object at 0x0000026C4EF405F8>
# 	.expm1 -> <syft.ast.callable.Callable object at 0x0000026C4EF40660>
# 	.fft -> Module:
#
# 	.fill_ -> <syft.ast.callable.Callable object at 0x0000026C4EF40730>
# 	.flatten -> <syft.ast.callable.Callable object at 0x0000026C4EF40798>
# 	.flip -> <syft.ast.callable.Callable object at 0x0000026C4EF40800>
# 	.floor_ -> <syft.ast.callable.Callable object at 0x0000026C4EF40868>
# 	.floor_divide -> <syft.ast.callable.Callable object at 0x0000026C4EF408D0>
# 	.floor -> <syft.ast.callable.Callable object at 0x0000026C4EF40938>
# 	.fmod -> <syft.ast.callable.Callable object at 0x0000026C4EF409A0>
# 	.frac_ -> <syft.ast.callable.Callable object at 0x0000026C4EF40A08>
# 	.frac -> <syft.ast.callable.Callable object at 0x0000026C4EF40A70>
# 	.from_numpy -> <syft.ast.callable.Callable object at 0x0000026C4EF40AD8>
# 	.gather -> <syft.ast.callable.Callable object at 0x0000026C4EF40B40>
# 	.ge -> <syft.ast.callable.Callable object at 0x0000026C4EF40BA8>
# 	.geqrf -> <syft.ast.callable.Callable object at 0x0000026C4EF40C10>
# 	.ger -> <syft.ast.callable.Callable object at 0x0000026C4EF40C78>
# 	.get_device -> <syft.ast.callable.Callable object at 0x0000026C4EF40CE0>
# 	.gt -> <syft.ast.callable.Callable object at 0x0000026C4EF40D48>
# 	.hardshrink -> <syft.ast.callable.Callable object at 0x0000026C4EF40DB0>
# 	.histc -> <syft.ast.callable.Callable object at 0x0000026C4EF40E18>
# 	.index_add -> <syft.ast.callable.Callable object at 0x0000026C4EF40E80>
# 	.index_copy -> <syft.ast.callable.Callable object at 0x0000026C4EF40EE8>
# 	.index_fill -> <syft.ast.callable.Callable object at 0x0000026C4EF40F50>
# 	.index_put_ -> <syft.ast.callable.Callable object at 0x0000026C4EF45048>
# 	.index_put -> <syft.ast.callable.Callable object at 0x0000026C4EF450B0>
# 	.index_select -> <syft.ast.callable.Callable object at 0x0000026C4EF45118>
# 	.int_repr -> <syft.ast.callable.Callable object at 0x0000026C4EF45180>
# 	.inverse -> <syft.ast.callable.Callable object at 0x0000026C4EF451E8>
# 	.is_complex -> <syft.ast.callable.Callable object at 0x0000026C4EF45250>
# 	.is_distributed -> <syft.ast.callable.Callable object at 0x0000026C4EF452B8>
# 	.is_floating_point -> <syft.ast.callable.Callable object at 0x0000026C4EF45320>
# 	.is_nonzero -> <syft.ast.callable.Callable object at 0x0000026C4EF45388>
# 	.is_same_size -> <syft.ast.callable.Callable object at 0x0000026C4EF453F0>
# 	.is_signed -> <syft.ast.callable.Callable object at 0x0000026C4EF45458>
# 	.isclose -> <syft.ast.callable.Callable object at 0x0000026C4EF454C0>
# 	.kthvalue -> <syft.ast.callable.Callable object at 0x0000026C4EF45528>
# 	.le -> <syft.ast.callable.Callable object at 0x0000026C4EF45590>
# 	.lerp -> <syft.ast.callable.Callable object at 0x0000026C4EF455F8>
# 	.lgamma -> <syft.ast.callable.Callable object at 0x0000026C4EF45660>
# 	.log_ -> <syft.ast.callable.Callable object at 0x0000026C4EF456C8>
# 	.log_softmax -> <syft.ast.callable.Callable object at 0x0000026C4EF45730>
# 	.log -> <syft.ast.callable.Callable object at 0x0000026C4EF45798>
# 	.log10_ -> <syft.ast.callable.Callable object at 0x0000026C4EF45800>
# 	.log10 -> <syft.ast.callable.Callable object at 0x0000026C4EF45868>
# 	.log1p_ -> <syft.ast.callable.Callable object at 0x0000026C4EF458D0>
# 	.log1p -> <syft.ast.callable.Callable object at 0x0000026C4EF45938>
# 	.log2_ -> <syft.ast.callable.Callable object at 0x0000026C4EF459A0>
# 	.log2 -> <syft.ast.callable.Callable object at 0x0000026C4EF45A08>
# 	.logdet -> <syft.ast.callable.Callable object at 0x0000026C4EF45A70>
# 	.logical_and -> <syft.ast.callable.Callable object at 0x0000026C4EF45AD8>
# 	.logical_not -> <syft.ast.callable.Callable object at 0x0000026C4EF45B40>
# 	.logical_or -> <syft.ast.callable.Callable object at 0x0000026C4EF45BA8>
# 	.logical_xor -> <syft.ast.callable.Callable object at 0x0000026C4EF45C10>
# 	.logsumexp -> <syft.ast.callable.Callable object at 0x0000026C4EF45C78>
# 	.lstsq -> <syft.ast.callable.Callable object at 0x0000026C4EF45CE0>
# 	.lt -> <syft.ast.callable.Callable object at 0x0000026C4EF45D48>
# 	.lu_solve -> <syft.ast.callable.Callable object at 0x0000026C4EF45DB0>
# 	.lu -> <syft.ast.callable.Callable object at 0x0000026C4EF45E18>
# 	.masked_fill -> <syft.ast.callable.Callable object at 0x0000026C4EF45E80>
# 	.masked_scatter -> <syft.ast.callable.Callable object at 0x0000026C4EF45EE8>
# 	.masked_select -> <syft.ast.callable.Callable object at 0x0000026C4EF45F50>
# 	.matmul -> <syft.ast.callable.Callable object at 0x0000026C4EF4A048>
# 	.matrix_power -> <syft.ast.callable.Callable object at 0x0000026C4EF4A0B0>
# 	.mean -> <syft.ast.callable.Callable object at 0x0000026C4EF4A118>
# 	.mm -> <syft.ast.callable.Callable object at 0x0000026C4EF4A180>
# 	.mode -> <syft.ast.callable.Callable object at 0x0000026C4EF4A1E8>
# 	.mul -> <syft.ast.callable.Callable object at 0x0000026C4EF4A250>
# 	.multinomial -> <syft.ast.callable.Callable object at 0x0000026C4EF4A2B8>
# 	.mv -> <syft.ast.callable.Callable object at 0x0000026C4EF4A320>
# 	.mvlgamma -> <syft.ast.callable.Callable object at 0x0000026C4EF4A388>
# 	.narrow -> <syft.ast.callable.Callable object at 0x0000026C4EF4A3F0>
# 	.ne -> <syft.ast.callable.Callable object at 0x0000026C4EF4A458>
# 	.neg_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4A4C0>
# 	.neg -> <syft.ast.callable.Callable object at 0x0000026C4EF4A528>
# 	.nonzero -> <syft.ast.callable.Callable object at 0x0000026C4EF4A590>
# 	.norm -> <syft.ast.callable.Callable object at 0x0000026C4EF4A5F8>
# 	.orgqr -> <syft.ast.callable.Callable object at 0x0000026C4EF4A660>
# 	.ormqr -> <syft.ast.callable.Callable object at 0x0000026C4EF4A6C8>
# 	.pinverse -> <syft.ast.callable.Callable object at 0x0000026C4EF4A730>
# 	.polygamma -> <syft.ast.callable.Callable object at 0x0000026C4EF4A798>
# 	.pow -> <syft.ast.callable.Callable object at 0x0000026C4EF4A800>
# 	.prelu -> <syft.ast.callable.Callable object at 0x0000026C4EF4A868>
# 	.q_per_channel_axis -> <syft.ast.callable.Callable object at 0x0000026C4EF4A8D0>
# 	.q_per_channel_scales -> <syft.ast.callable.Callable object at 0x0000026C4EF4A938>
# 	.q_per_channel_zero_points -> <syft.ast.callable.Callable object at 0x0000026C4EF4A9A0>
# 	.q_scale -> <syft.ast.callable.Callable object at 0x0000026C4EF4AA08>
# 	.q_zero_point -> <syft.ast.callable.Callable object at 0x0000026C4EF4AA70>
# 	.qr -> <syft.ast.callable.Callable object at 0x0000026C4EF4AAD8>
# 	.reciprocal_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4AB40>
# 	.reciprocal -> <syft.ast.callable.Callable object at 0x0000026C4EF4ABA8>
# 	.relu_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4AC10>
# 	.relu -> <syft.ast.callable.Callable object at 0x0000026C4EF4AC78>
# 	.remainder -> <syft.ast.callable.Callable object at 0x0000026C4EF4ACE0>
# 	.renorm -> <syft.ast.callable.Callable object at 0x0000026C4EF4AD48>
# 	.repeat_interleave -> <syft.ast.callable.Callable object at 0x0000026C4EF4ADB0>
# 	.reshape -> <syft.ast.callable.Callable object at 0x0000026C4EF4AE18>
# 	.resize_as_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4AE80>
# 	.roll -> <syft.ast.callable.Callable object at 0x0000026C4EF4AEE8>
# 	.rot90 -> <syft.ast.callable.Callable object at 0x0000026C4EF4AF50>
# 	.round_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4F048>
# 	.round -> <syft.ast.callable.Callable object at 0x0000026C4EF4F0B0>
# 	.rsqrt_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4F118>
# 	.rsqrt -> <syft.ast.callable.Callable object at 0x0000026C4EF4F180>
# 	.scatter_add -> <syft.ast.callable.Callable object at 0x0000026C4EF4F1E8>
# 	.scatter -> <syft.ast.callable.Callable object at 0x0000026C4EF4F250>
# 	.select -> <syft.ast.callable.Callable object at 0x0000026C4EF4F2B8>
# 	.sigmoid_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4F320>
# 	.sigmoid -> <syft.ast.callable.Callable object at 0x0000026C4EF4F388>
# 	.sign -> <syft.ast.callable.Callable object at 0x0000026C4EF4F3F0>
# 	.sin_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4F458>
# 	.sin -> <syft.ast.callable.Callable object at 0x0000026C4EF4F4C0>
# 	.sinh_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4F528>
# 	.sinh -> <syft.ast.callable.Callable object at 0x0000026C4EF4F590>
# 	.slogdet -> <syft.ast.callable.Callable object at 0x0000026C4EF4F5F8>
# 	.softmax -> <syft.ast.callable.Callable object at 0x0000026C4EF4F660>
# 	.solve -> <syft.ast.callable.Callable object at 0x0000026C4EF4F6C8>
# 	.sort -> <syft.ast.callable.Callable object at 0x0000026C4EF4F730>
# 	.split_with_sizes -> <syft.ast.callable.Callable object at 0x0000026C4EF4F798>
# 	.split -> <syft.ast.callable.Callable object at 0x0000026C4EF4F800>
# 	.sqrt_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4F868>
# 	.sqrt -> <syft.ast.callable.Callable object at 0x0000026C4EF4F8D0>
# 	.square_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4F938>
# 	.square -> <syft.ast.callable.Callable object at 0x0000026C4EF4F9A0>
# 	.squeeze -> <syft.ast.callable.Callable object at 0x0000026C4EF4FA08>
# 	.stack -> <syft.ast.callable.Callable object at 0x0000026C4EF4FA70>
# 	.std -> <syft.ast.callable.Callable object at 0x0000026C4EF4FAD8>
# 	.stft -> <syft.ast.callable.Callable object at 0x0000026C4EF4FB40>
# 	.sub -> <syft.ast.callable.Callable object at 0x0000026C4EF4FBA8>
# 	.sum -> <syft.ast.callable.Callable object at 0x0000026C4EF4FC10>
# 	.svd -> <syft.ast.callable.Callable object at 0x0000026C4EF4FC78>
# 	.symeig -> <syft.ast.callable.Callable object at 0x0000026C4EF4FCE0>
# 	.t -> <syft.ast.callable.Callable object at 0x0000026C4EF4FD48>
# 	.take -> <syft.ast.callable.Callable object at 0x0000026C4EF4FDB0>
# 	.tan_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4FE18>
# 	.tan -> <syft.ast.callable.Callable object at 0x0000026C4EF4FE80>
# 	.tanh_ -> <syft.ast.callable.Callable object at 0x0000026C4EF4FEE8>
# 	.tanh -> <syft.ast.callable.Callable object at 0x0000026C4EF4FF50>
# 	.topk -> <syft.ast.callable.Callable object at 0x0000026C4EF54048>
# 	.trace -> <syft.ast.callable.Callable object at 0x0000026C4EF540B0>
# 	.transpose -> <syft.ast.callable.Callable object at 0x0000026C4EF54118>
# 	.triangular_solve -> <syft.ast.callable.Callable object at 0x0000026C4EF54180>
# 	.tril -> <syft.ast.callable.Callable object at 0x0000026C4EF541E8>
# 	.triu -> <syft.ast.callable.Callable object at 0x0000026C4EF54250>
# 	.true_divide -> <syft.ast.callable.Callable object at 0x0000026C4EF542B8>
# 	.trunc_ -> <syft.ast.callable.Callable object at 0x0000026C4EF54320>
# 	.trunc -> <syft.ast.callable.Callable object at 0x0000026C4EF54388>
# 	.unique_consecutive -> <syft.ast.callable.Callable object at 0x0000026C4EF543F0>
# 	.unique -> <syft.ast.callable.Callable object at 0x0000026C4EF54458>
# 	.unsqueeze -> <syft.ast.callable.Callable object at 0x0000026C4EF544C0>
# 	.var -> <syft.ast.callable.Callable object at 0x0000026C4EF54528>
# 	.unsafe_chunk -> <syft.ast.callable.Callable object at 0x0000026C4EF54590>
# 	.absolute -> <syft.ast.callable.Callable object at 0x0000026C4EF545F8>
# 	.acosh_ -> <syft.ast.callable.Callable object at 0x0000026C4EF54660>
# 	.acosh -> <syft.ast.callable.Callable object at 0x0000026C4EF546C8>
# 	.asinh_ -> <syft.ast.callable.Callable object at 0x0000026C4EF54730>
# 	.asinh -> <syft.ast.callable.Callable object at 0x0000026C4EF54798>
# 	.atanh_ -> <syft.ast.callable.Callable object at 0x0000026C4EF54800>
# 	.atanh -> <syft.ast.callable.Callable object at 0x0000026C4EF54868>
# 	.deg2rad_ -> <syft.ast.callable.Callable object at 0x0000026C4EF548D0>
# 	.deg2rad -> <syft.ast.callable.Callable object at 0x0000026C4EF54938>
# 	.fliplr -> <syft.ast.callable.Callable object at 0x0000026C4EF549A0>
# 	.flipud -> <syft.ast.callable.Callable object at 0x0000026C4EF54A08>
# 	.isfinite -> <syft.ast.callable.Callable object at 0x0000026C4EF54A70>
# 	.isinf -> <syft.ast.callable.Callable object at 0x0000026C4EF54AD8>
# 	.isnan -> <syft.ast.callable.Callable object at 0x0000026C4EF54B40>
# 	.logaddexp -> <syft.ast.callable.Callable object at 0x0000026C4EF54BA8>
# 	.logaddexp2 -> <syft.ast.callable.Callable object at 0x0000026C4EF54C10>
# 	.logcumsumexp -> <syft.ast.callable.Callable object at 0x0000026C4EF54C78>
# 	.rad2deg_ -> <syft.ast.callable.Callable object at 0x0000026C4EF54CE0>
# 	.rad2deg -> <syft.ast.callable.Callable object at 0x0000026C4EF54D48>
# 	.istft -> <syft.ast.callable.Callable object at 0x0000026C4EF54DB0>
# 	.amax -> <syft.ast.callable.Callable object at 0x0000026C4EF54E18>
# 	.amin -> <syft.ast.callable.Callable object at 0x0000026C4EF54E80>
# 	.arccos -> <syft.ast.callable.Callable object at 0x0000026C4EF54EE8>
# 	.arccos_ -> <syft.ast.callable.Callable object at 0x0000026C4EF54F50>
# 	.arccosh -> <syft.ast.callable.Callable object at 0x0000026C4EF59048>
# 	.arccosh_ -> <syft.ast.callable.Callable object at 0x0000026C4EF590B0>
# 	.arcsin -> <syft.ast.callable.Callable object at 0x0000026C4EF59118>
# 	.arcsin_ -> <syft.ast.callable.Callable object at 0x0000026C4EF59180>
# 	.arcsinh -> <syft.ast.callable.Callable object at 0x0000026C4EF591E8>
# 	.arcsinh_ -> <syft.ast.callable.Callable object at 0x0000026C4EF59250>
# 	.arctan -> <syft.ast.callable.Callable object at 0x0000026C4EF592B8>
# 	.arctan_ -> <syft.ast.callable.Callable object at 0x0000026C4EF59320>
# 	.arctanh -> <syft.ast.callable.Callable object at 0x0000026C4EF59388>
# 	.arctanh_ -> <syft.ast.callable.Callable object at 0x0000026C4EF593F0>
# 	.clip -> <syft.ast.callable.Callable object at 0x0000026C4EF59458>
# 	.clip_ -> <syft.ast.callable.Callable object at 0x0000026C4EF594C0>
# 	.count_nonzero -> <syft.ast.callable.Callable object at 0x0000026C4EF59528>
# 	.divide -> <syft.ast.callable.Callable object at 0x0000026C4EF59590>
# 	.exp2 -> <syft.ast.callable.Callable object at 0x0000026C4EF595F8>
# 	.exp2_ -> <syft.ast.callable.Callable object at 0x0000026C4EF59660>
# 	.fix -> <syft.ast.callable.Callable object at 0x0000026C4EF596C8>
# 	.fix_ -> <syft.ast.callable.Callable object at 0x0000026C4EF59730>
# 	.gcd -> <syft.ast.callable.Callable object at 0x0000026C4EF59798>
# 	.gcd_ -> <syft.ast.callable.Callable object at 0x0000026C4EF59800>
# 	.greater -> <syft.ast.callable.Callable object at 0x0000026C4EF59868>
# 	.greater_equal -> <syft.ast.callable.Callable object at 0x0000026C4EF598D0>
# 	.heaviside -> <syft.ast.callable.Callable object at 0x0000026C4EF59938>
# 	.hypot -> <syft.ast.callable.Callable object at 0x0000026C4EF599A0>
# 	.i0 -> <syft.ast.callable.Callable object at 0x0000026C4EF59A08>
# 	.i0_ -> <syft.ast.callable.Callable object at 0x0000026C4EF59A70>
# 	.isneginf -> <syft.ast.callable.Callable object at 0x0000026C4EF59AD8>
# 	.isposinf -> <syft.ast.callable.Callable object at 0x0000026C4EF59B40>
# 	.isreal -> <syft.ast.callable.Callable object at 0x0000026C4EF59BA8>
# 	.lcm -> <syft.ast.callable.Callable object at 0x0000026C4EF59C10>
# 	.lcm_ -> <syft.ast.callable.Callable object at 0x0000026C4EF59C78>
# 	.less -> <syft.ast.callable.Callable object at 0x0000026C4EF59CE0>
# 	.less_equal -> <syft.ast.callable.Callable object at 0x0000026C4EF59D48>
# 	.logit -> <syft.ast.callable.Callable object at 0x0000026C4EF59DB0>
# 	.logit_ -> <syft.ast.callable.Callable object at 0x0000026C4EF59E18>
# 	.maximum -> <syft.ast.callable.Callable object at 0x0000026C4EF59E80>
# 	.minimum -> <syft.ast.callable.Callable object at 0x0000026C4EF59EE8>
# 	.matrix_exp -> <syft.ast.callable.Callable object at 0x0000026C4EF59F50>
# 	.multiply -> <syft.ast.callable.Callable object at 0x0000026C4EF60048>
# 	.nanquantile -> <syft.ast.callable.Callable object at 0x0000026C4EF600B0>
# 	.nansum -> <syft.ast.callable.Callable object at 0x0000026C4EF60118>
# 	.negative -> <syft.ast.callable.Callable object at 0x0000026C4EF60180>
# 	.negative_ -> <syft.ast.callable.Callable object at 0x0000026C4EF601E8>
# 	.nextafter -> <syft.ast.callable.Callable object at 0x0000026C4EF60250>
# 	.outer -> <syft.ast.callable.Callable object at 0x0000026C4EF602B8>
# 	.quantile -> <syft.ast.callable.Callable object at 0x0000026C4EF60320>
# 	.sgn -> <syft.ast.callable.Callable object at 0x0000026C4EF60388>
# 	.signbit -> <syft.ast.callable.Callable object at 0x0000026C4EF603F0>
# 	.subtract -> <syft.ast.callable.Callable object at 0x0000026C4EF60458>
# 	.unsafe_split -> <syft.ast.callable.Callable object at 0x0000026C4EF604C0>
# 	.vdot -> <syft.ast.callable.Callable object at 0x0000026C4EF60528>
# 	.movedim -> <syft.ast.callable.Callable object at 0x0000026C4EF60590>
# 	.unsafe_split_with_sizes -> <syft.ast.callable.Callable object at 0x0000026C4EF605F8>
# 	.cuda -> Module:
# 		.is_available -> <syft.ast.callable.Callable object at 0x0000026C4EF606C8>
#
# 	.device -> <syft.ast.klass.Class object at 0x0000026C4EF60730>
# 	.random -> Module:
# 		.initial_seed -> <syft.ast.callable.Callable object at 0x0000026C4EF608D0>
#
# 	.zeros_like -> <syft.ast.callable.Callable object at 0x0000026C4EF60938>
# 	.manual_seed -> <syft.ast.callable.Callable object at 0x0000026C4EF609A0>
# 	.Generator -> <syft.ast.klass.Class object at 0x0000026C4EF60A08>
# 	.utils -> Module:
# 		.data -> Module:
# 			.DataLoader -> <syft.ast.klass.Class object at 0x0000026C4EF64D48>
# 			.dataloader -> Module:
# 				._SingleProcessDataLoaderIter -> <syft.ast.klass.Class object at 0x0000026C4EF64EE8>
#
#
#
# 	.optim -> Module:
# 		.ASGD -> <syft.ast.klass.Class object at 0x0000026C4EF68320>
# 		.Adadelta -> <syft.ast.klass.Class object at 0x0000026C4EF684C0>
# 		.Adagrad -> <syft.ast.klass.Class object at 0x0000026C4EF68660>
# 		.Adam -> <syft.ast.klass.Class object at 0x0000026C4EF68800>
# 		.AdamW -> <syft.ast.klass.Class object at 0x0000026C4EF689A0>
# 		.Adamax -> <syft.ast.klass.Class object at 0x0000026C4EF68B40>
# 		.LBFGS -> <syft.ast.klass.Class object at 0x0000026C4EF68CE0>
# 		.Optimizer -> <syft.ast.klass.Class object at 0x0000026C4EF68E80>
# 		.RMSprop -> <syft.ast.klass.Class object at 0x0000026C4EF6F0B0>
# 		.Rprop -> <syft.ast.klass.Class object at 0x0000026C4EF6F250>
# 		.SGD -> <syft.ast.klass.Class object at 0x0000026C4EF6F3F0>
# 		.SparseAdam -> <syft.ast.klass.Class object at 0x0000026C4EF6F590>
# 		.lr_scheduler -> Module:
# 			.StepLR -> <syft.ast.klass.Class object at 0x0000026C4EF6F798>
#
#
# 	.no_grad -> <syft.ast.klass.Class object at 0x0000026C4EF6F8D0>
# 	.autograd -> Module:
# 		.grad_mode -> Module:
# 			.no_grad -> <syft.ast.klass.Class object at 0x0000026C4EF6FA08>
#
#
# 	.distributions -> Module:
# 		.Categorical -> <syft.ast.klass.Class object at 0x0000026C4F01D4C0>
#
# 	.kron -> <syft.ast.callable.Callable object at 0x0000026C4F01DA08>
# 	.msort -> <syft.ast.callable.Callable object at 0x0000026C4F01DB40>
# 	.row_stack -> <syft.ast.callable.Callable object at 0x0000026C4F01DBA8>
# 	.moveaxis -> <syft.ast.callable.Callable object at 0x0000026C4F01DE80>
# 	.tensor_split -> <syft.ast.callable.Callable object at 0x0000026C4F024048>
# 	.tile -> <syft.ast.callable.Callable object at 0x0000026C4F024180>
# 	.fmin -> <syft.ast.callable.Callable object at 0x0000026C4F024388>
# 	.ldexp -> <syft.ast.callable.Callable object at 0x0000026C4F0243F0>
# 	.igamma -> <syft.ast.callable.Callable object at 0x0000026C4F024528>
# 	.float_power -> <syft.ast.callable.Callable object at 0x0000026C4F024A70>
# 	.xlogy -> <syft.ast.callable.Callable object at 0x0000026C4F024BA8>
# 	.copysign -> <syft.ast.callable.Callable object at 0x0000026C4F024C10>
# 	.nanmedian -> <syft.ast.callable.Callable object at 0x0000026C4F024C78>
# 	.igammac -> <syft.ast.callable.Callable object at 0x0000026C4F024CE0>
# 	.diff -> <syft.ast.callable.Callable object at 0x0000026C4F024E18>
# 	.sinc -> <syft.ast.callable.Callable object at 0x0000026C4F024F50>
# 	.column_stack -> <syft.ast.callable.Callable object at 0x0000026C4F02A1E8>
# 	.pixel_unshuffle -> <syft.ast.callable.Callable object at 0x0000026C4F02A320>
# 	.swapaxes -> <syft.ast.callable.Callable object at 0x0000026C4F02A5F8>
# 	.nan_to_num -> <syft.ast.callable.Callable object at 0x0000026C4F02A660>
# 	.inner -> <syft.ast.callable.Callable object at 0x0000026C4F02A6C8>
# 	.fmax -> <syft.ast.callable.Callable object at 0x0000026C4F02A730>
# 	.ravel -> <syft.ast.callable.Callable object at 0x0000026C4F02AAD8>
# 	.broadcast_to -> <syft.ast.callable.Callable object at 0x0000026C4F02AB40>
# 	.swapdims -> <syft.ast.callable.Callable object at 0x0000026C4F02AD48>

# %%
def BMI_calculator(w_ptr, h_ptr):
    
    bmi_ptr = 0

    ##TODO

    "Write your code here for calculating bmi_ptr"
    h_ptr_square = h_ptr.float().square()
    bmi_ptr = (w_ptr / h_ptr_square) * 10000

    ###

    return bmi_ptr


def weight_status(w_ptr, h_ptr):

    status = None

    bmi_ptr  = BMI_calculator(w_ptr, h_ptr)

    ##TODO
    
    bmi_ptr = bmi_ptr.get(
        request_block=True,
        reason="accept",
        timeout_secs=10,
    )
    
    if bmi_ptr.int() in range(19, 25):
        status = 'Normal'
    elif bmi_ptr.int() in range(25, 30):
        status = 'Overweight'
    elif bmi_ptr.int() in range(30, 40):
        status = 'Obese'
    else:
        status = 'Out of range'

    """Write your code here. 
    Possible values for status: 
    Normal, 
    Overweight, 
    Obese, 
    Out of range
    """""

    ###
    
    return status

# %%
for i in range(0, 6):
    bmi_ptr = BMI_calculator(weights_ptr[i], heights_ptr[i])

# %%
statuses = []
for i in range(0, 6):
    status = weight_status(weights_ptr[i], heights_ptr[i])
    print("Weight of Person", i + 1, "is", status)
    statuses.append(status)

assert statuses == ["Normal", "Overweight", "Obese", "Normal", "Overweight", "Normal"]
# Out:
# Weight of Person 1 is Normal
# Weight of Person 2 is Overweight
# Weight of Person 3 is Obese
# Weight of Person 4 is Normal
# Weight of Person 5 is Overweight
# Weight of Person 6 is Normal
